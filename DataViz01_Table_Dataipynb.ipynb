# %% [markdown]
# <a href="https://colab.research.google.com/github/Supathatkh/data_viz_2022/blob/main/DataViz01_Table_Dataipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['Name'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ##Parallel Coordinates

# %%
pd.plotting.parallel_coordinates(df, 'Name') #pandas.พล็อต.กราฟparallel(ชื่อตาราง , ชื่อcolumn)

# %%
pd.plotting.parallel_coordinates(df, 'Name',cols = ['SepalLength', 'PetalLength'])

# %%
pd.plotting.parallel_coordinates(df, 'Name',cols = ['SepalLength', 'PetalLength']); #; จะลบข้อความที่มันจะแสดงออกมา

# %% [markdown]
# ### change color

# %%
pd.plotting.parallel_coordinates(df, 'Name',color = ['r', 'y', 'k'])

# %%
pd.plotting.parallel_coordinates(df, 'Name',color = [[0.5,0.5,0.5], [0,0,0.8], [0.2,0.4,0.7]])

# %% [markdown]
# ### specify color by colormap

# %%
pd.plotting.parallel_coordinates(df, 'Name',colormap='Set1')

# %% [markdown]
# ## Matplotllib

# %%
from matplotlib import pyplot as plt

# %%
import  matplotlib

# %% [markdown]
# ### Heatmap matrix

# %%
matplotlib.rcParams['figure.figsize']=[25,25] #กำหนดขนาดของ figure
plt.imshow(df.iloc[:,:-1],interpolation='nearest')

# %%
plt.imshow(df.iloc[:,:-1],interpolation='nearest',cmap= 'hot')

# %% [markdown]
# ### Subplot

# %%
matplotlib.rcParams['figure.figsize'] =[10,10]

# %%
plt.subplot(1,3,1) # subplot(มีกี่แถว, มีกี่หลัก, เป็นตัวที่เท่าไหร่)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap ='hot')

plt.subplot(1,3,2)
plt.imshow(df.iloc[50:100,:-1],interpolation='nearest',cmap ='hot')

plt.subplot(1,3,3)
plt.imshow(df.iloc[100:150,:-1],interpolation='nearest',cmap ='hot')

# %%
plt.subplot(1,2,1)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap ='hot')

plt.subplot(1,2,2)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap ='hot' ,alpha =0.5) #alphha กำหนดความโปร่งใส

# %%
plt.subplot(1,4,1)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap ='hot')

plt.subplot(1,4,2)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap ='hot' ,alpha =0.2)

plt.subplot(1,4,3)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap ='hot' ,alpha =0.5)

plt.subplot(1,4,4)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap ='hot' ,alpha =0.8)

# %%
plt.subplot(1,2,1)
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5,0.5],[0,0,0.8,0.5],[0.2,0.4,0.7,0.5]])

plt.subplot(1,2,2)
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5],[0,0,0.8],[0.2,0.4,0.7]])

# %%
pd.plotting.parallel_coordinates(df,'Name' ,color=[[0.5,0.5,0.5,0.5],[0,0,0.8,0.5],[0.2,0.4,0.7,0.5]])

# %% [markdown]
# ## HW finalGP 1
#
# วาดกราฟ parallel coordinate เปรียบเทียบ [อายุ, เพศ] โดยใช้ class เป็น risk (เลือกมาแค่ 3 risk)

# %%
import pandas as pd #นำเข้า pandas แทนที่ด้วย pd
import os

# %%
from google.colab import drive #นำเข้าข้อมูลจาก drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/dataviz_2021_data'
# Out:
# Mounted at /content/drive

# %%
data_file_path = os.path.join(path,'pm-20-jan-2021.csv')
data_df = pd.read_csv(data_file_path)

# %%
set(data_df['risk']) # ดูข้อมูลของคอลัมน์ 'risk'
# Out:
# {"Cluster Memory 90's กรุงเทพมหานคร.",
#  'Cluster New Jazz กรุงเทพมหานคร.',
#  'Cluster จันทบุรี',
#  'Cluster ชลบุรี',
#  'Cluster ชลบุรี โรงเบียร์ 90',
#  'Cluster ตราด (สถานที่ลักลอบเล่นการพนันแสนตุ้ง)',
#  'Cluster ตลาดบางพลี',
#  'Cluster บ่อนพัทยา/ชลบุรี',
#  'Cluster บ่อนไก่อ่างทอง',
#  'Cluster ระยอง',
#  'Cluster สมุทรสาคร',
#  'Cluster โรงงาน Big Star',
#  'Cluster โรงงาน standard can',
#  'State Quarantine',
#  nan,
#  'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน',
#  'คนต่างชาติเดินทางมาจากต่างประเทศ',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คนไทยเดินทางมาจากต่างประเทศ',
#  'ตรวจก่อนทำหัตถการ',
#  'บุคลากรด้านการแพทย์และสาธารณสุข',
#  'ปอดอักเสบ (Pneumonia)',
#  'ผู้ติดเชื้อในประเทศ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ',
#  'พิธีกรรมทางศาสนา',
#  'ระบุไม่ได้',
#  'ศูนย์กักกัน ผู้ต้องกัก',
#  'สถานบันเทิง',
# ...

# %%
data_df
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %%
data1 = data_df[data_df['risk']== 'สถานบันเทิง'] #แสดง risk ที่มีสถานบันเทิง
data1
# Out:
#          No. announce_date  ... district_of_onset         risk
# 56        57     3/11/2020  ...               NaN  สถานบันเทิง
# 59        60     3/12/2020  ...               NaN  สถานบันเทิง
# 60        61     3/12/2020  ...               NaN  สถานบันเทิง
# 61        62     3/12/2020  ...           บางพลัด  สถานบันเทิง
# 62        63     3/12/2020  ...            สายไหม  สถานบันเทิง
# ...      ...           ...  ...               ...          ...
# 11046  11047     1/14/2021  ...            สัตหีบ  สถานบันเทิง
# 11047  11048     1/14/2021  ...            สัตหีบ  สถานบันเทิง
# 11344  11345     1/15/2021  ...           ศรีราชา  สถานบันเทิง
# 12418  12419     1/18/2021  ...             เมือง  สถานบันเทิง
# 12606  12607     1/20/2021  ...             บางแค  สถานบันเทิง
#
# [315 rows x 10 columns]

# %%
data2 = data_df[data_df['risk']== 'สนามมวย']
data2
# Out:
#        No. announce_date  ... district_of_onset     risk
# 81      82     3/14/2020  ...          ลาดพร้าว  สนามมวย
# 82      83     3/15/2020  ...               NaN  สนามมวย
# 83      84     3/15/2020  ...               NaN  สนามมวย
# 84      85     3/15/2020  ...               NaN  สนามมวย
# 85      86     3/15/2020  ...               NaN  สนามมวย
# ...    ...           ...  ...               ...      ...
# 1978  1979      4/4/2020  ...               NaN  สนามมวย
# 1979  1980      4/4/2020  ...               NaN  สนามมวย
# 2635  2636     4/15/2020  ...               NaN  สนามมวย
# 2726  2727     4/18/2020  ...            พระนคร  สนามมวย
# 2787  2788     4/20/2020  ...           พระโขนง  สนามมวย
#
# [274 rows x 10 columns]

# %%
data3 = data_df[data_df['risk']== 'สัมผัสผู้ป่วยยืนยัน'] 
data3
# Out:
#        No. announce_date  ... district_of_onset                 risk
# 7628  7629      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
# 7629  7630      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
# 7632  7633      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
#
# [3 rows x 10 columns]

# %%
 data4 = pd.concat([data1,data2]) #รวมตาราง data1 กับ data2
 data5 = pd.concat([data4,data3]) #รวมตาราง data4 กับ data3
 data5
# Out:
#        No. announce_date  ... district_of_onset                 risk
# 56      57     3/11/2020  ...               NaN          สถานบันเทิง
# 59      60     3/12/2020  ...               NaN          สถานบันเทิง
# 60      61     3/12/2020  ...               NaN          สถานบันเทิง
# 61      62     3/12/2020  ...           บางพลัด          สถานบันเทิง
# 62      63     3/12/2020  ...            สายไหม          สถานบันเทิง
# ...    ...           ...  ...               ...                  ...
# 2726  2727     4/18/2020  ...            พระนคร              สนามมวย
# 2787  2788     4/20/2020  ...           พระโขนง              สนามมวย
# 7628  7629      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
# 7629  7630      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
# 7632  7633      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
#
# [592 rows x 10 columns]

# %%
 data4 = pd.concat([data1,data2]) #รวมตาราง data1 กับ data2
 data5 = pd.concat([data4,data3]) #รวมตาราง data4 กับ data3
 data5
# Out:
#        No. announce_date  ... district_of_onset                 risk
# 56      57     3/11/2020  ...               NaN          สถานบันเทิง
# 59      60     3/12/2020  ...               NaN          สถานบันเทิง
# 60      61     3/12/2020  ...               NaN          สถานบันเทิง
# 61      62     3/12/2020  ...           บางพลัด          สถานบันเทิง
# 62      63     3/12/2020  ...            สายไหม          สถานบันเทิง
# ...    ...           ...  ...               ...                  ...
# 2726  2727     4/18/2020  ...            พระนคร              สนามมวย
# 2787  2788     4/20/2020  ...           พระโขนง              สนามมวย
# 7628  7629      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
# 7629  7630      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
# 7632  7633      1/3/2021  ...         เมืองตราด  สัมผัสผู้ป่วยยืนยัน
#
# [592 rows x 10 columns]

# %%
data6 = data5[['sex','age','risk']]

# %%
data6['sex'].replace({'ชาย':1,'หญิง':50}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data6['risk'].replace({'สถานบันเทิง':'entertainment place','สนามมวย':'boxing stadium','สัมผัสผู้ป่วยยืนยัน':'Close Contact'}, inplace=True) #เปลี่ยนไทยเป็นอังกฤษ เนื่องจากกราฟไม่รองรับภาษาไทย
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data6
# Out:
#       sex   age                 risk
# 56     50  27.0  entertainment place
# 59     50  29.0  entertainment place
# 60      1  32.0  entertainment place
# 61     50  33.0  entertainment place
# 62      1  32.0  entertainment place
# ...   ...   ...                  ...
# 2726    1  70.0       boxing stadium
# 2787   50  47.0       boxing stadium
# 7628    1  43.0        Close Contact
# 7629    1  16.0        Close Contact
# 7632   50  44.0        Close Contact
#
# [592 rows x 3 columns]

# %%
data6['risk'].unique() #เช็คข้อมมูลในคอลัมน์ risk
# Out:
# array(['entertainment place', 'boxing stadium', 'Close Contact'],
#       dtype=object)

# %%
pd.plotting.parallel_coordinates(data6,'risk',colormap='Set2' )
